# %% [markdown]
# <a href="https://colab.research.google.com/github/trighpro123/BT_tuan13/blob/main/Fashion_mnist(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import RMSprop
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import np_utils

#Load và phan chia dư liệu
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
print(np.shape(x_train))
print(np.shape(x_test))

# Xử lý dữ liệu thành 0-1
# x_train=x_train.reshape(60000,784)
# # hàng nối tiếp hàng sao cho đủ 784 chứ ko phải 28 nữa. 784 tín hiệu vào
# x_test=x_test.reshape(10000,784)
x_train=x_train.astype('float32') # Ép kiểu
x_test=x_test.astype('float32')
x_train/=255 # Các pixel number có giá trị từ [0,255] về giới hạn 0-1
x_test/=255
y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
from keras.models import Sequential
from keras.layers import Dense,Activation,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from keras.utils import np_utils
# #Tạo mo hình 

model=Sequential()
# BLock 1
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(28,28,1))) 
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same')) 
model.add(MaxPooling2D((2,2)))
#Block 2
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same')) 
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
#Block 3
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same')) 
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same')) 
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()

# # Biên dịch
model.compile(loss='categorical_crossentropy',optimizer=RMSprop(),metrics='accuracy')
history=model.fit(x_train,y_train,batch_size=128,epochs=30,verbose=1,validation_data=(x_test,y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 512)               590336
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 881,898
# Trainable params: 881,898
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 469/469 [==============================] - 31s 40ms/step - loss: 0.5007 - accuracy: 0.8228 - val_loss: 0.3523 - val_accuracy: 0.8776
# Epoch 2/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.2765 - accuracy: 0.8991 - val_loss: 0.3087 - val_accuracy: 0.8771
# Epoch 3/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.2276 - accuracy: 0.9155 - val_loss: 0.2697 - val_accuracy: 0.9105
# Epoch 4/30
# 469/469 [==============================] - 18s 39ms/step - loss: 0.1995 - accuracy: 0.9253 - val_loss: 0.2555 - val_accuracy: 0.9081
# Epoch 5/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1762 - accuracy: 0.9351 - val_loss: 0.2521 - val_accuracy: 0.9148
# Epoch 6/30
# 469/469 [==============================] - 18s 37ms/step - loss: 0.1573 - accuracy: 0.9423 - val_loss: 0.2801 - val_accuracy: 0.9233
# Epoch 7/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1423 - accuracy: 0.9484 - val_loss: 0.2450 - val_accuracy: 0.9172
# Epoch 8/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1311 - accuracy: 0.9531 - val_loss: 0.3271 - val_accuracy: 0.9205
# Epoch 9/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1234 - accuracy: 0.9555 - val_loss: 0.3465 - val_accuracy: 0.9215
# Epoch 10/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1150 - accuracy: 0.9591 - val_loss: 0.2672 - val_accuracy: 0.9197
# Epoch 11/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1109 - accuracy: 0.9614 - val_loss: 0.3505 - val_accuracy: 0.9178
# Epoch 12/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1082 - accuracy: 0.9622 - val_loss: 0.3271 - val_accuracy: 0.9192
# Epoch 13/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1027 - accuracy: 0.9639 - val_loss: 0.3671 - val_accuracy: 0.9148
# Epoch 14/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1003 - accuracy: 0.9648 - val_loss: 0.6212 - val_accuracy: 0.9139
# Epoch 15/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0999 - accuracy: 0.9657 - val_loss: 0.3347 - val_accuracy: 0.9200
# Epoch 16/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0945 - accuracy: 0.9676 - val_loss: 0.4466 - val_accuracy: 0.9084
# Epoch 17/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0945 - accuracy: 0.9683 - val_loss: 0.3887 - val_accuracy: 0.9160
# Epoch 18/30
# 469/469 [==============================] - 18s 37ms/step - loss: 0.0947 - accuracy: 0.9686 - val_loss: 0.7169 - val_accuracy: 0.9163
# Epoch 19/30
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0903 - accuracy: 0.9699 - val_loss: 0.5484 - val_accuracy: 0.9172
# Epoch 20/30
# 469/469 [==============================] - 18s 37ms/step - loss: 0.0887 - accuracy: 0.9711 - val_loss: 0.6469 - val_accuracy: 0.9070
# Epoch 21/30
# 469/469 [==============================] - 18s 37ms/step - loss: 0.0931 - accuracy: 0.9705 - val_loss: 0.4760 - val_accuracy: 0.9189
# Epoch 22/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0897 - accuracy: 0.9718 - val_loss: 0.4581 - val_accuracy: 0.9146
# Epoch 23/30
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0899 - accuracy: 0.9702 - val_loss: 0.4852 - val_accuracy: 0.9193
# Epoch 24/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0880 - accuracy: 0.9723 - val_loss: 1.0080 - val_accuracy: 0.9125
# Epoch 25/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0880 - accuracy: 0.9729 - val_loss: 0.5256 - val_accuracy: 0.9211
# Epoch 26/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0815 - accuracy: 0.9739 - val_loss: 0.6565 - val_accuracy: 0.9188
# Epoch 27/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.1038 - accuracy: 0.9756 - val_loss: 0.4871 - val_accuracy: 0.9142
# Epoch 28/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0770 - accuracy: 0.9754 - val_loss: 0.3619 - val_accuracy: 0.9093
# Epoch 29/30
# 469/469 [==============================] - 18s 37ms/step - loss: 0.0840 - accuracy: 0.9750 - val_loss: 0.6345 - val_accuracy: 0.9184
# Epoch 30/30
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0816 - accuracy: 0.9754 - val_loss: 0.4021 - val_accuracy: 0.9145

# %%
# # Vẽ đồ thị bằng plt
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'],loc='upperleft')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Unrecognized location 'upperleft'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   if sys.path[0] == '':

# %%
model.save_weights("fashion_mnist_CNN_weights.h5")
